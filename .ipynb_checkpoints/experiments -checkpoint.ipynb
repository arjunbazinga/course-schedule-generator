# %%
import pandas as pd

# %% [markdown]
# # Things Worth doing
# * Individual calendar for students
#     * with location
# * Get location/Schedule of a teacher
# * Get the amount of students a teacher handles,
#     * Find out who has the maximum power to change overall marks
#     * Number of students summed over all the courses he gives
#     *
# * Most popular courses, least popular courses
# * Who takes what

# %% [markdown]
# # Slot System Parsing

# %%
df = pd.read_csv("Slot System.csv")

# %%
df
# Out:
#                                            Unnamed: 0     Unnamed: 1  \
# 0                                      Forenoon Slots            NaN
# 1                                                 NaN            NaN
# 2                                                 NaN  08:00 - 08:55
# 3                                                 Mon              G
# 4                                                 NaN            NaN
# 5                                                 Tue            NaN
# 6                                                 NaN            NaN
# 7                                                 Wed              G
# 8                                                 NaN            NaN
# 9                                                 Thu              G
# 10                                                NaN            NaN
# 11                                                Fri            NaN
# 12                                                NaN            NaN
# 13                                                Sat            NaN
# 14                                                NaN            NaN
# 15                                                NaN            NaN
# 16                                                NaN            NaN
# 17                                    Afternoon Slots            NaN
# 18                                                NaN            NaN
# 19                                                NaN  08:00 - 08:55
# 20                                                Mon            NaN
# 21                                                NaN            NaN
# 22                                                Tue            NaN
# 23                                                NaN            NaN
# 24                                                Wed            NaN
# 25                                                NaN            NaN
# 26                                                Thu            NaN
# 27                                                NaN            NaN
# 28                                                Fri            NaN
# 29                                                NaN            NaN
# 30                                                NaN            NaN
# 31  Note: Schedule of Laboratories will be prepare...            NaN
#
#        Unnamed: 2     Unnamed: 3     Unnamed: 4     Unnamed: 5     Unnamed: 6  \
# 0             NaN            NaN            NaN            NaN            NaN
# 1             NaN            NaN            NaN            NaN            NaN
# 2   09:00 - 09:55  10:00 - 10:55  11:00 - 11:55  12:00 - 12:55  13:00 - 13:55
# 3               B              A              J              K          Lunch
# 4             NaN            NaN            NaN            NaN            NaN
# 5               F              C              B              E            NaN
# 6             NaN            NaN            NaN            NaN            NaN
# 7               F              C              D              E            NaN
# 8             NaN            NaN            NaN            NaN            NaN
# 9               F              A              J              K            NaN
# 10            NaN            NaN            NaN            NaN            NaN
# 11              B              A              D              E            NaN
# 12            NaN            NaN            NaN            NaN            NaN
# 13            NaN            NaN              I              K            NaN
# 14            NaN            NaN            NaN            NaN            NaN
# 15            NaN            NaN            NaN            NaN            NaN
# 16            NaN            NaN            NaN            NaN            NaN
# 17            NaN            NaN            NaN            NaN            NaN
# 18            NaN            NaN            NaN            NaN            NaN
# 19  09:00 - 09:55  10:00 - 10:55  11:00 - 11:55  12:00 - 12:55  13:00 - 13:55
# 20            NaN            NaN            NaN          Lunch              W
# 21            NaN            NaN            NaN            NaN            NaN
# 22            NaN            NaN            NaN            NaN              Z
# 23            NaN            NaN            NaN            NaN            NaN
# 24            NaN            NaN              T            NaN              V
# 25            NaN            NaN            NaN            NaN            NaN
# 26            NaN            NaN            NaN            NaN              Z
# 27            NaN            NaN            NaN            NaN            NaN
# 28            NaN            NaN              T            NaN              U
# 29            NaN            NaN            NaN            NaN            NaN
# 30            NaN            NaN            NaN            NaN            NaN
# 31            NaN            NaN            NaN            NaN            NaN
#
#        Unnamed: 7     Unnamed: 8     Unnamed: 9    Unnamed: 10
# 0             NaN            NaN            NaN            NaN
# 1             NaN            NaN            NaN            NaN
# 2   14:00 - 14:55  15:00 - 15:55  16:00 - 16:55  17:00 - 17:55
# 3             NaN            NaN            NaN              I
# 4             NaN            NaN            NaN            NaN
# 5             NaN            NaN            NaN              I
# 6             NaN            NaN            NaN            NaN
# 7             NaN            NaN            NaN              H
# 8             NaN            NaN            NaN            NaN
# 9               D            NaN            NaN              C
# 10            NaN            NaN            NaN            NaN
# 11            NaN            NaN            NaN              J
# 12            NaN            NaN            NaN            NaN
# 13              H              H            NaN            NaN
# 14            NaN            NaN            NaN            NaN
# 15            NaN            NaN            NaN            NaN
# 16            NaN            NaN            NaN            NaN
# 17            NaN            NaN            NaN            NaN
# 18            NaN            NaN            NaN            NaN
# 19  14:00 - 14:55  15:00 - 15:55  16:00 - 16:55  17:00 - 17:55
# 20              Z              U              X              Y
# 21            NaN            NaN            NaN            NaN
# 22              V              S              U              X
# 23            NaN            NaN            NaN            NaN
# 24              Y              S              X            NaN
# 25            NaN            NaN            NaN            NaN
# 26              T              W              S            NaN
# 27            NaN            NaN            NaN            NaN
# 28              V              Y              W            NaN
# 29            NaN            NaN            NaN            NaN
# 30            NaN            NaN            NaN            NaN
# 31            NaN            NaN            NaN            NaN

# %%
t = df[df.columns[0]].notnull()
for i in range(1,len(df.columns)):
    t = t | df[df.columns[i]].notnull()

# %%
df = df[t]

# %%
df
# Out:
#                                            Unnamed: 0     Unnamed: 1  \
# 0                                      Forenoon Slots            NaN
# 2                                                 NaN  08:00 - 08:55
# 3                                                 Mon              G
# 5                                                 Tue            NaN
# 7                                                 Wed              G
# 9                                                 Thu              G
# 11                                                Fri            NaN
# 13                                                Sat            NaN
# 17                                    Afternoon Slots            NaN
# 19                                                NaN  08:00 - 08:55
# 20                                                Mon            NaN
# 22                                                Tue            NaN
# 24                                                Wed            NaN
# 26                                                Thu            NaN
# 28                                                Fri            NaN
# 31  Note: Schedule of Laboratories will be prepare...            NaN
#
#        Unnamed: 2     Unnamed: 3     Unnamed: 4     Unnamed: 5     Unnamed: 6  \
# 0             NaN            NaN            NaN            NaN            NaN
# 2   09:00 - 09:55  10:00 - 10:55  11:00 - 11:55  12:00 - 12:55  13:00 - 13:55
# 3               B              A              J              K          Lunch
# 5               F              C              B              E            NaN
# 7               F              C              D              E            NaN
# 9               F              A              J              K            NaN
# 11              B              A              D              E            NaN
# 13            NaN            NaN              I              K            NaN
# 17            NaN            NaN            NaN            NaN            NaN
# 19  09:00 - 09:55  10:00 - 10:55  11:00 - 11:55  12:00 - 12:55  13:00 - 13:55
# 20            NaN            NaN            NaN          Lunch              W
# 22            NaN            NaN            NaN            NaN              Z
# 24            NaN            NaN              T            NaN              V
# 26            NaN            NaN            NaN            NaN              Z
# 28            NaN            NaN              T            NaN              U
# 31            NaN            NaN            NaN            NaN            NaN
#
#        Unnamed: 7     Unnamed: 8     Unnamed: 9    Unnamed: 10
# 0             NaN            NaN            NaN            NaN
# 2   14:00 - 14:55  15:00 - 15:55  16:00 - 16:55  17:00 - 17:55
# 3             NaN            NaN            NaN              I
# 5             NaN            NaN            NaN              I
# 7             NaN            NaN            NaN              H
# 9               D            NaN            NaN              C
# 11            NaN            NaN            NaN              J
# 13              H              H            NaN            NaN
# 17            NaN            NaN            NaN            NaN
# 19  14:00 - 14:55  15:00 - 15:55  16:00 - 16:55  17:00 - 17:55
# 20              Z              U              X              Y
# 22              V              S              U              X
# 24              Y              S              X            NaN
# 26              T              W              S            NaN
# 28              V              Y              W            NaN
# 31            NaN            NaN            NaN            NaN

# %%
df[df["Unnamed: 0"].apply(lambda x: len(str(x)) == 3)]
# Out:
#    Unnamed: 0     Unnamed: 1     Unnamed: 2     Unnamed: 3     Unnamed: 4  \
# 2         NaN  08:00 - 08:55  09:00 - 09:55  10:00 - 10:55  11:00 - 11:55
# 3         Mon              G              B              A              J
# 5         Tue            NaN              F              C              B
# 7         Wed              G              F              C              D
# 9         Thu              G              F              A              J
# 11        Fri            NaN              B              A              D
# 13        Sat            NaN            NaN            NaN              I
# 19        NaN  08:00 - 08:55  09:00 - 09:55  10:00 - 10:55  11:00 - 11:55
# 20        Mon            NaN            NaN            NaN            NaN
# 22        Tue            NaN            NaN            NaN            NaN
# 24        Wed            NaN            NaN            NaN              T
# 26        Thu            NaN            NaN            NaN            NaN
# 28        Fri            NaN            NaN            NaN              T
#
#        Unnamed: 5     Unnamed: 6     Unnamed: 7     Unnamed: 8     Unnamed: 9  \
# 2   12:00 - 12:55  13:00 - 13:55  14:00 - 14:55  15:00 - 15:55  16:00 - 16:55
# 3               K          Lunch            NaN            NaN            NaN
# 5               E            NaN            NaN            NaN            NaN
# 7               E            NaN            NaN            NaN            NaN
# 9               K            NaN              D            NaN            NaN
# 11              E            NaN            NaN            NaN            NaN
# 13              K            NaN              H              H            NaN
# 19  12:00 - 12:55  13:00 - 13:55  14:00 - 14:55  15:00 - 15:55  16:00 - 16:55
# 20          Lunch              W              Z              U              X
# 22            NaN              Z              V              S              U
# 24            NaN              V              Y              S              X
# 26            NaN              Z              T              W              S
# 28            NaN              U              V              Y              W
#
#       Unnamed: 10
# 2   17:00 - 17:55
# 3               I
# 5               I
# 7               H
# 9               C
# 11              J
# 13            NaN
# 19  17:00 - 17:55
# 20              Y
# 22              X
# 24            NaN
# 26            NaN
# 28            NaN

# %%
df = df[df["Unnamed: 0"].apply(lambda x: len(str(x)) == 3)]

# %%
df.values
# Out:
# array([[nan, '08:00 - 08:55', '09:00 - 09:55', '10:00 - 10:55',
#         '11:00 - 11:55', '12:00 - 12:55', '13:00 - 13:55',
#         '14:00 - 14:55', '15:00 - 15:55', '16:00 - 16:55',
#         '17:00 - 17:55'],
#        ['Mon', 'G', 'B', 'A', 'J', 'K', 'Lunch', nan, nan, nan, 'I'],
#        ['Tue', nan, 'F', 'C', 'B', 'E', nan, nan, nan, nan, 'I'],
#        ['Wed', 'G', 'F', 'C', 'D', 'E', nan, nan, nan, nan, 'H'],
#        ['Thu', 'G', 'F', 'A', 'J', 'K', nan, 'D', nan, nan, 'C'],
#        ['Fri', nan, 'B', 'A', 'D', 'E', nan, nan, nan, nan, 'J'],
#        ['Sat', nan, nan, nan, 'I', 'K', nan, 'H', 'H', nan, nan],
#        [nan, '08:00 - 08:55', '09:00 - 09:55', '10:00 - 10:55',
#         '11:00 - 11:55', '12:00 - 12:55', '13:00 - 13:55',
#         '14:00 - 14:55', '15:00 - 15:55', '16:00 - 16:55',
#         '17:00 - 17:55'],
#        ['Mon', nan, nan, nan, nan, 'Lunch', 'W', 'Z', 'U', 'X', 'Y'],
#        ['Tue', nan, nan, nan, nan, nan, 'Z', 'V', 'S', 'U', 'X'],
#        ['Wed', nan, nan, nan, 'T', nan, 'V', 'Y', 'S', 'X', nan],
#        ['Thu', nan, nan, nan, nan, nan, 'Z', 'T', 'W', 'S', nan],
#        ['Fri', nan, nan, nan, 'T', nan, 'U', 'V', 'Y', 'W', nan]],
#       dtype=object)

# %%
time = df.values[0]

# %%
time
# Out:
# array([nan, '08:00 - 08:55', '09:00 - 09:55', '10:00 - 10:55',
#        '11:00 - 11:55', '12:00 - 12:55', '13:00 - 13:55', '14:00 - 14:55',
#        '15:00 - 15:55', '16:00 - 16:55', '17:00 - 17:55'], dtype=object)

# %%
d = {}

for row in df.values:
    for i in range(len(row)):
        c = row[i]
        if len(str(c)) == 1:
            day = row[0]
            t = time[i]
            if c not in d:
                d[c] = []
            d[c].append((day,t))

# %%
d
# Out:
# {'G': [('Mon', '08:00 - 08:55'),
#   ('Wed', '08:00 - 08:55'),
#   ('Thu', '08:00 - 08:55')],
#  'B': [('Mon', '09:00 - 09:55'),
#   ('Tue', '11:00 - 11:55'),
#   ('Fri', '09:00 - 09:55')],
#  'A': [('Mon', '10:00 - 10:55'),
#   ('Thu', '10:00 - 10:55'),
#   ('Fri', '10:00 - 10:55')],
#  'J': [('Mon', '11:00 - 11:55'),
#   ('Thu', '11:00 - 11:55'),
#   ('Fri', '17:00 - 17:55')],
#  'K': [('Mon', '12:00 - 12:55'),
#   ('Thu', '12:00 - 12:55'),
#   ('Sat', '12:00 - 12:55')],
#  'I': [('Mon', '17:00 - 17:55'),
#   ('Tue', '17:00 - 17:55'),
#   ('Sat', '11:00 - 11:55')],
#  'F': [('Tue', '09:00 - 09:55'),
#   ('Wed', '09:00 - 09:55'),
#   ('Thu', '09:00 - 09:55')],
#  'C': [('Tue', '10:00 - 10:55'),
#   ('Wed', '10:00 - 10:55'),
#   ('Thu', '17:00 - 17:55')],
#  'E': [('Tue', '12:00 - 12:55'),
#   ('Wed', '12:00 - 12:55'),
#   ('Fri', '12:00 - 12:55')],
#  'D': [('Wed', '11:00 - 11:55'),
#   ('Thu', '14:00 - 14:55'),
#   ('Fri', '11:00 - 11:55')],
#  'H': [('Wed', '17:00 - 17:55'),
#   ('Sat', '14:00 - 14:55'),
#   ('Sat', '15:00 - 15:55')],
#  'W': [('Mon', '13:00 - 13:55'),
#   ('Thu', '15:00 - 15:55'),
#   ('Fri', '16:00 - 16:55')],
#  'Z': [('Mon', '14:00 - 14:55'),
#   ('Tue', '13:00 - 13:55'),
#   ('Thu', '13:00 - 13:55')],
#  'U': [('Mon', '15:00 - 15:55'),
#   ('Tue', '16:00 - 16:55'),
#   ('Fri', '13:00 - 13:55')],
#  'X': [('Mon', '16:00 - 16:55'),
#   ('Tue', '17:00 - 17:55'),
#   ('Wed', '16:00 - 16:55')],
#  'Y': [('Mon', '17:00 - 17:55'),
#   ('Wed', '14:00 - 14:55'),
#   ('Fri', '15:00 - 15:55')],
#  'V': [('Tue', '14:00 - 14:55'),
#   ('Wed', '13:00 - 13:55'),
#   ('Fri', '14:00 - 14:55')],
#  'S': [('Tue', '15:00 - 15:55'),
#   ('Wed', '15:00 - 15:55'),
#   ('Thu', '16:00 - 16:55')],
#  'T': [('Wed', '11:00 - 11:55'),
#   ('Thu', '14:00 - 14:55'),
#   ('Fri', '11:00 - 11:55')]}

# %%
def get_slots(path_to_csv):
    
    df = pd.read_csv(path_to_csv)

    t = df[df.columns[0]].notnull()
    for i in range(1,len(df.columns)):
        t = t | df[df.columns[i]].notnull()

    df = df[t]

    df[df["Unnamed: 0"].apply(lambda x: len(str(x)) == 3)]

    df = df[df["Unnamed: 0"].apply(lambda x: len(str(x)) == 3)]


    time = df.values[0]

    d = {}

    for row in df.values:
        for i in range(len(row)):
            c = row[i]
            if len(str(c)) == 1:
                day = row[0]
                t = time[i]
                if c not in d:
                    d[c] = []
                d[c].append((day,t))
    
    return d

# %%
slot_details = get_slots("Slot System.csv")

# %% [markdown]
# # Course list parsing

# %%
df = pd.read_csv("List of Courses.csv",header=1)

# %%
t = df[df["Course Code"].apply(lambda x: x.split()[1][0] in ["4","6"])]

# %%
t = t[t["Total Student"].apply(lambda x: x.isnumeric())]

# %%
t["Total Student"] = t["Total Student"].apply(lambda x: int(x))

# %%
t = t.sort_values(by="Total Student")

# %%
t.tail(50)
# Out:
#        #   Course Code                                              Title  \
# 99   100    ME 464/764                                      Microrobotics
# 135  136        MA 620                     Partial Differential Equations
# 36    37    ME 407/607                                 Biofluid Mechanics
# 151  152        MA 680                           Computational Techniques
# 117  118        MA 612                                        Analysis-II
# 156  157        MA 640                                          Algebra-I
# 82    83    ME 434/634                        Principle of Product Design
# 145  146        MM 656               Experimental Techniques in Materials
# 86    87        CE 448                              Pre-stressed Concrete
# 109  110    EE 428/628                         Advanced Memory Technology
# 123  124    MA 452/652                               Theory of Transforms
# 158  159        ME 650              Materials Characterization Techniques
# 110  111    ME 460/660                      Technology of Surface Coating
# 120  121    AA 478/678                                      Space Weather
# 149  150        PH 624                                        Electronics
# 21    22        CE 438  Probabilistic and Statistical Methods in Civil...
# 118  119        PH 620                              Statistical Mechanics
# 131  132        PH 622                Fundamentals of Solid State Physics
# 89    90        PH 660                       Nuclear and Particle Physics
# 139  140        CH 642            Applied Inorganic and Nuclear Chemistry
# 126  127        CH 624     Total Synthesis and Natural Products Chemistry
# 113  114        CH 604                             Molecular Spectroscopy
# 101  102        CH 602         Thermodynamics, Kinetics, Electrochemistry
# 13    14    EE 440/640                  Analog and Mixed Signal IC Design
# 35    36    ME 432/632                       Vibrations and Noise Control
# 20    21    MM 442/642                    Quality Assurance in Metallurgy
# 94    95       AA 608N                                    Astrostatistics
# 125  126    MM 488/688                                    Electroceramics
# 144  145    ME 437/637                                 Fracture Mechanics
# 107  108  AA 474N/674N                                    Radio Astronomy
# 22    23    EE 430/630                              Analog CMOS IC Design
# 93    94       IHS 482  Introduction to International Development and ...
# 138  139        CE 408                             Foundation Engineering
# 112  113        CE 404                           Design of Structures-III
# 12    13        CE 402                        Water Resources Engineering
# 33    34        CE 406                      Transportation Engineering-II
# 96    97  AA 472N/672N               Galactic and Extragalactic Astronomy
# 141  142    CS 420/620                                   Embedded Systems
# 108  109    CS 417/617                  Cryptography and Network Security
# 15    16    MM 402/602                  Design and Selection of Materials
# 85    86    MM 430/730   Two Dimensional Materials and Electronic Devices
# 97    98    HS 418/618                             Sustainability Studies
# 38    39    EE 446/646                      Information and Coding Theory
# 19    20        ME 401                                  Machine Design-II
# 74    75   IHS 443/643                         Contemporary Short Fiction
# 150  151       IHS 444                Literature of the Twentieth Century
# 133  134    CS 419/619                                    Computer Vision
# 63    64    ME 472/672                            Reliability Engineering
# 157  158       IHS 402  Twentieth Century World History: Critical Pers...
# 66    67    HS 412/612                        Contemporary Indian Thought
#
#         _L_T_P_C_   Total Student          Course Coordinator  \
# 99   2 - 1 - 0 - 3             12            Dr. I. A. Palani
# 135  2 - 1 - 0 - 3             12           Dr. Antony Vijesh
# 36   2 - 1 - 0 - 3             12           Dr. S. Dhinakaran
# 151  3 - 0 - 2 - 4             12           Dr. Santanu Manna
# 117  3 - 1 - 0 - 4             12        Dr. Bibekananda Maji
# 156  3 - 1 - 0 - 4             12           Dr. Anand Prakash
# 82   2 - 1 - 0 - 3             13      Dr. Pavan Kumar Kankar
# 145  2 - 0 - 2 - 3             13     Dr. Dhirendra Kumar Rai
# 86   2 - 1 - 0 - 3             14          Dr. Kaustav Bakshi
# 109  2 - 1 - 0 - 3             14       Dr. Shaibal Mukherjee
# 123  2 - 1 - 0 - 3             14           Dr. Sanjeev Singh
# 158  2 - 0 - 2 - 3             15     Dr. Satyajit Chatterjee
# 110  2 - 1 - 0 - 3             16         Dr. Kazi Sabiruddin
# 120  2 - 1 - 0 - 3             17             Dr. Saurabh Das
# 149  2 - 1 - 0 - 3             18        Prof. Krushna Mavani
# 21   2 - 1 - 0 - 3             18            Dr. Guru Prakash
# 118  2 - 1 - 0 - 3             18      Prof. Subhendu Rakshit
# 131  2 - 1 - 0 - 3             18         Dr. Preeti A. Bhobe
# 89   2 - 1 - 0 - 3             18       Dr. Manavendra Mahato
# 139  2 - 1 - 0 - 3             20    Prof. Suman Mukhopadhyay
# 126  2 - 1 - 0 - 3             20            Dr. Apurba K Das
# 113  2 - 1 - 0 - 3             20       Dr. Anjan Chakraborty
# 101  2 - 1 - 0 - 3             20      Dr. Tridib Kumar Sarma
# 13   2 - 1 - 0 - 3             22  Dr. Santosh K. Vishvakarma
# 35   2 - 1 - 0 - 3             23           Prof. Anand Parey
# 20   2 - 0 - 2 - 3             23           Dr. Hemant Borkar
# 94   2 - 1 - 0 - 3             23          Dr. Suman Majumdar
# 125  2 - 1 - 0 - 3             24             Dr. Sunil Kumar
# 144  2 - 1 - 0 - 3             24          Dr. Indrasen Singh
# 107  2 - 1 - 0 - 3             25           Dr. Abhirup Datta
# 22   2 - 1 - 0 - 3             28        Prof. Abhinav Kranti
# 93   2 - 1 - 0 - 3             34    Dr. Ashok Kumar Mocherla
# 138  2 - 0 - 2 - 3             36          Dr. Neelima Satyam
# 112  2 - 1 - 0 - 3             36     Prof. Sandeep Chaudhary
# 12   2 - 1 - 0 - 3             36      Dr. Manish Kumar Goyal
# 33   2 - 1 - 0 - 3             36         Dr. Abhishek Rajput
# 96   2 - 1 - 0 - 3             39          Dr. Bhargav Vaidya
# 141  2 - 1 - 0 - 3             41         Dr. Gourinath Banda
# 108  2 - 1 - 0 - 3             42     Dr. Bodhisatwa Mazumdar
# 15   2 - 1 - 2 - 3             42   Dr. Dudekula Althaf Basha
# 85   2 - 1 - 0 - 3             43     Dr. Ajay Kumar Kushwaha
# 97   3 - 0 - 0 - 3             46           Dr. Pritee Sharma
# 38   2 - 1 - 0 - 3             47          Prof. Vimal Bhatia
# 19   2 - 2 - 0 - 4             56      Dr. Shailesh Kundalwal
# 74   2 - 1 - 0 - 3             63           Dr. Nirmala Menon
# 150  3 - 0 - 0 - 3             87          Dr. Ananya Ghoshal
# 133  2 - 1 - 0 - 3             99           Dr. Surya Prakash
# 63   2 - 0 - 2 - 3            106          Dr. Bhupesh K. Lad
# 157  3 - 0 - 0 - 3            172              Dr. C. Upendra
# 66   2 - 1 - 0 - 3            184         Dr. Shomik Dasgupta
#
#                                      Course Instructor Slot  Room No
# 99                                   Dr. I. A. Palani,    T        0
# 135                                 Dr. Antony Vijesh,    W  1E-202A
# 36                                  Dr. S. Dhinakaran,    C        0
# 151  Dr. Bapan Ghosh, Dr. Santanu Manna, Dr. Sk. Sa...    Y        0
# 117                              Dr. Bibekananda Maji,    V  1E-202B
# 156                                 Dr. Anand Prakash,    Z        0
# 82                             Dr. Pavan Kumar Kankar,    S       sb
# 145                           Dr. Dhirendra Kumar Rai,    X   1D-207
# 86                                 Dr. Kaustav Bakshi,    S   1E-505
# 109                             Dr. Shaibal Mukherjee,    U        0
# 123                                 Dr. Sanjeev Singh,    V  1E-202A
# 158                           Dr. Satyajit Chatterjee,    Z        0
# 110                               Dr. Kazi Sabiruddin,    U        0
# 120               Dr. Bhargav Vaidya, Dr. Saurabh Das,    V   1E-505
# 149                              Prof. Krushna Mavani,    E   1E-506
# 21                                   Dr. Guru Prakash,    B   1E-408
# 118     Dr. Sudip Chakraborty, Prof. Subhendu Rakshit,    V   1E-404
# 131   Dr. Preeti A. Bhobe, Dr. Sudeshna Chattopadhyay,    W   1E-404
# 89        Dr. Manavendra Mahato, Dr. Srimanta Pakhira,    S   1E-404
# 139      Dr. Shaikh M Mobin, Prof. Suman Mukhopadhyay,    X   SB-115
# 126           Dr. Apurba K Das, Dr. Chelvam Venkatesh,    W   SB-115
# 113  Dr. Anjan Chakraborty, Dr. Tushar Kanti Mukher...    V   SB-115
# 101       Dr. Satya S. Bulusu, Dr. Tridib Kumar Sarma,    U   SB-115
# 13    Dr. Santosh K. Vishvakarma, Dr. Saptarshi Ghosh,    A        0
# 35                                  Prof. Anand Parey,    C        0
# 20                                  Dr. Hemant Borkar,    B   1E-406
# 94                                 Dr. Suman Majumdar,    S   1E-505
# 125                                   Dr. Sunil Kumar,    V   1E-406
# 144                                Dr. Indrasen Singh,    X        0
# 107      Dr. Abhirup Datta, Dr. Manoneeta Chakraborty,    U   1E-505
# 22                               Prof. Abhinav Kranti,    B        0
# 93        Dr. Akshaya Kumar, Dr. Ashok Kumar Mocherla,    S        0
# 138              Dr. Lalit Borana, Dr. Neelima Satyam,    X        0
# 112                           Prof. Sandeep Chaudhary,    V   1E-408
# 12                             Dr. Manish Kumar Goyal,    A        0
# 33                                Dr. Abhishek Rajput,    C        0
# 96          Dr. Bhargav Vaidya, Dr. Siddharth S. Malu,    T   1E-408
# 141                               Dr. Gourinath Banda,    X   1E-506
# 108                           Dr. Bodhisatwa Mazumdar,    U   1E-506
# 15                          Dr. Dudekula Althaf Basha,    A   1E-406
# 85                            Dr. Ajay Kumar Kushwaha,    S   1E-406
# 97               Dr. Nirmala Menon, Dr. Pritee Sharma,    T        0
# 38                                 Prof. Vimal Bhatia,    C        0
# 19                             Dr. Shailesh Kundalwal,    B        0
# 74                                  Dr. Nirmala Menon,    J        0
# 150                                Dr. Ananya Ghoshal,    Y        0
# 133                                 Dr. Surya Prakash,    W        0
# 63                                 Dr. Bhupesh K. Lad,    F        0
# 157                                    Dr. C. Upendra,    Z   1B-201
# 66                                Dr. Shomik Dasgupta,    H   1B-201

# %%
event_details = {code:{"title":name,"slot":slot} for code, name,slot in zip(df["Course Code"],df["Title"],df["Slot"])}

# %%
slot_details[event_details["ME 202"]["slot"]]
# Out:
# [('Mon', '10:00 - 10:55'), ('Thu', '10:00 - 10:55'), ('Fri', '10:00 - 10:55')]

# %% [markdown]
# # Parsing room details

# %% [markdown]
# # Get Courses from registration sheet

# %%
import bs4

# %%
registration_sheet_path = "Course Registration.html"
with open(registration_sheet_path, 'r') as content_file:
    content = content_file.read()

# %%
content
# Out:
# '<!DOCTYPE html>\n<!-- saved from url=(0052)https://academic.iiti.ac.in:8443/courseListprint.jsp -->\n<html><head><meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n        \n        <title>Course Registration</title>\n    <style type="text/css">\n               \n.auto-style1 {\n  font-family: "Franklin Gothic Medium", "Arial Narrow", Arial, sans-serif;\n}\n.auto-style2 {\n  text-align: center;\n}\n.auto-style3 {\n  color: #0000AD;\n}\n</style>\n    \n  <style type="text/css">\n        \n        .top{\nvertical-align:top;\n}\n.bottom{\nvertical-align:bottom;\n}\n        </style>\n     <style>\n.break { page-break-before: always; }\n</style>\n    <style type="text/css"> \n   hr {page-break-before: always}\n   th {font-size: 1.5; font-weight: normal; font-family: "Calibri", "Calibri",Calibri,Calibri;}\n   td {font-size: 1.5; font-family: "Calibri", "Calibri", Calibri;}\n</style>\n    </head>\n    \n    \n  \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    \n    <body>\n    \n  \n   \n      <div style="page-break-after:always"></div>\n   <br>    \n            <center>\n  \n                <table border="0" cellspacing="0" cellpadding="0" width="95%">\n  <tbody><tr>\n      <td align="right">\n      \n      <img src="./Course Registration_files/iiti.png" alt="IIT INDORE" width="100" height="100">\n      </td>\n      <td>\n          \n          <table width="100%">\n          <tbody><tr>\n              <td width="100%"><br><br>\n      <font size="4">&nbsp; </font>\n      <font size="5" face="Century Gothic" color="#003388"> <b>Indian Institute of Technology Indore</b></font><font size="4">\n    </font><br>\n    <p></p>\n</td>\n              </tr>\n          \n      <tr>           \n<td width="100%">\n  <font size="4">&nbsp; </font>\n  <font size="3" face="Century Gothic" color="#003388"><b>Course Registration Form</b></font><font size="4">\n    <br></font><br>\n\n                        <p></p>\n\n                                \n</td>\n              </tr>                                \n                     </tbody></table>           \n   \n           </td>\n                                 </tr>\n                                \n                                </tbody></table>\n            </center>\n            \n   \n   \n  \n        \n        <center>\n        <table border="0" cellspacing="0" cellpadding="0" width="90%">\n          <tbody><tr>\n        <td>  \n         <b>Year(Semester):</b>&nbsp;&nbsp; <u>2020&nbsp;(Spring)</u>\n        </td>\n        \n          </tr>\n        \n        <tr>\n            <td><br><b>Roll No.: </b>&nbsp;&nbsp; 160001007\n                </td>\n                <td><br><b>Name: </b>&nbsp;&nbsp; ARJUN SRIVASATAVA\n                </td>\n                </tr>\n            \n            \n            \n  <tr>\n            \n            <td><br><b>Discipline/Center/School: </b>&nbsp;&nbsp;\n                                                                    Computer Science and Engineering\n                                                                    \n                \n                </td>\n                   <td><br><b>Program: </b>&nbsp;&nbsp; B.Tech.\n                </td>\n                </tr>        \n <tr>\n        \n        \n            <td><br><b>Specialization: </b>&nbsp;&nbsp;\n                                                                    Computer Science and Engineering\n                                                                    \n                \n                \n                </td>\n                 \n                   <td><br><b>&nbsp;\n                </b></td>\n                </tr> \n                \n                \n                \n                <tr>\n            <td><br><b>Credit Registered: </b>&nbsp;&nbsp;  \n                    141.5\n                    \n                </td>\n                    \n                \n              \n                \n            ...

# %%
soup = bs4.BeautifulSoup(content)

# %%
tables = soup.find_all("table")

# %%
df = pd.read_html(str(tables[3]))[0]

# %%
courses = df["CourseCode"].dropna()

# %%
# Out:
# 0        CE 438
# 1    CS 419/619
# 2    HS 412/612
# 3       IHS 402
# 4    ME 472/672
# 5    MM 430/730
# Name: CourseCode, dtype: object

# %%
code,title, day,start,end = [],[],[],[],[]
time = []
for cc in courses:
    for d,t in slot_details[event_details[cc]["slot"]]:
        code.append(cc)
        title.append(event_details[cc]["title"])
        day.append(d)
        s,e = t.split("-")
        start.append(s.strip()+":00")
        end.append(e+":00")

# %%
df = pd.DataFrame([code,title,day,start,end]).T

# %%
df.columns = ["code","title","day","start","end"]

# %%
df.sort_values(by="day")
# Out:
#           code                                              title  day  \
# 2       CE 438  Probabilistic and Statistical Methods in Civil...  Fri
# 5   CS 419/619                                    Computer Vision  Fri
# 0       CE 438  Probabilistic and Statistical Methods in Civil...  Mon
# 9      IHS 402  Twentieth Century World History: Critical Pers...  Mon
# 3   CS 419/619                                    Computer Vision  Mon
# 7   HS 412/612                        Contemporary Indian Thought  Sat
# 8   HS 412/612                        Contemporary Indian Thought  Sat
# 4   CS 419/619                                    Computer Vision  Thu
# 11     IHS 402  Twentieth Century World History: Critical Pers...  Thu
# 14  ME 472/672                            Reliability Engineering  Thu
# 17  MM 430/730   Two Dimensional Materials and Electronic Devices  Thu
# 1       CE 438  Probabilistic and Statistical Methods in Civil...  Tue
# 10     IHS 402  Twentieth Century World History: Critical Pers...  Tue
# 12  ME 472/672                            Reliability Engineering  Tue
# 15  MM 430/730   Two Dimensional Materials and Electronic Devices  Tue
# 16  MM 430/730   Two Dimensional Materials and Electronic Devices  Wed
# 13  ME 472/672                            Reliability Engineering  Wed
# 6   HS 412/612                        Contemporary Indian Thought  Wed
#
#        start        end
# 2   09:00:00   09:55:00
# 5   16:00:00   16:55:00
# 0   09:00:00   09:55:00
# 9   14:00:00   14:55:00
# 3   13:00:00   13:55:00
# 7   14:00:00   14:55:00
# 8   15:00:00   15:55:00
# 4   15:00:00   15:55:00
# 11  13:00:00   13:55:00
# 14  09:00:00   09:55:00
# 17  16:00:00   16:55:00
# 1   11:00:00   11:55:00
# 10  13:00:00   13:55:00
# 12  09:00:00   09:55:00
# 15  15:00:00   15:55:00
# 16  15:00:00   15:55:00
# 13  09:00:00   09:55:00
# 6   17:00:00   17:55:00

# %%
from datetime import datetime

# %%
today = datetime.today()

# %%
today
# Out:
# datetime.datetime(2020, 1, 4, 18, 12, 45, 17241)

# %%
end = datetime(2020, 5, 6, 23, 59, 59, 0)

# %%
end = datetime(2020, 1, 6, 23, 59, 59, 0)

# %%
from datetime import timedelta

# %%
date = today
while date < end: 
    day= date.strftime('%a')
    for row in df[df["day"]=day].values:
        
    
    date += timedelta(days=1)
# Out:
# Sun
# Mon
# Tue

# %%
ans.sort(key=lambda x: (days[x[0]],x[1]))

# %%
days = ["Mon","Tue","Wed","Thu","Fri","Sat"]
days = {days[i]:i for i  in range(len(days)) }

# %%
ans[0]
# Out:
# ('Mon',
#  '09:00 - 09:55',
#  'CE 438',
#  'Probabilistic and Statistical Methods in Civil Engineering')

# %%
days
# Out:
# {'Mon': 0, 'Tue': 1, 'Wed': 2, 'Thu': 3, 'Fri': 4, 'Sat': 5}

# %%
from ics import Calendar, Event

# %%
c = Calendar()

# %%
e = Event()
e.name = "My cool event"
e.begin = '2020-01-03 18:00:00'
e.end =

# %%
c.events
# Out:
# {<Event 'My cool event' begin:2020-01-03T18:00:00+00:00 end:2020-01-03T18:00:00+00:00>}

# %%
with open('.ics', 'w') as f:
    f.write(str(c))

# %%
str(c)
# Out:
# 'BEGIN:VCALENDAR\r\nBEGIN:VEVENT\r\nDTSTART:20200103T180000Z\r\nSUMMARY:My cool event\r\nUID:b1f50870-9ab6-4a6c-b052-3fe2baf0ce16@b1f5.org\r\nEND:VEVENT\r\nPRODID:ics.py - http://git.io/lLljaA\r\nVERSION:2.0\r\nEND:VCALENDAR'
