# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\idinn\Downloads\Copy of Class Time Table for 2020 Spring Semester_Version II - Slot System.csv')

# %%
df
# Out:
#                                            Unnamed: 0     Unnamed: 1  \
# 0                                      Forenoon Slots            NaN
# 1                                                 NaN            NaN
# 2                                                 NaN  08:00 - 08:55
# 3                                                 Mon              G
# 4                                                 NaN            NaN
# 5                                                 Tue            NaN
# 6                                                 NaN            NaN
# 7                                                 Wed              G
# 8                                                 NaN            NaN
# 9                                                 Thu              G
# 10                                                NaN            NaN
# 11                                                Fri            NaN
# 12                                                NaN            NaN
# ...

# %%
t = df[df.columns[0]].notnull()
for i in range(1,len(df.columns)):
    t = t | df[df.columns[i]].notnull()

# %%
df[t]
# Out:
#                                            Unnamed: 0     Unnamed: 1  \
# 0                                      Forenoon Slots            NaN
# 2                                                 NaN  08:00 - 08:55
# 3                                                 Mon              G
# 5                                                 Tue            NaN
# 7                                                 Wed              G
# 9                                                 Thu              G
# 11                                                Fri            NaN
# 13                                                Sat            NaN
# 17                                    Afternoon Slots            NaN
# 19                                                NaN  08:00 - 08:55
# 20                                                Mon            NaN
# 22                                                Tue            NaN
# 24                                                Wed            NaN
# ...

# %%
d = {}

# %%
from collections import namedtuple

# %%
interval = namedtuple("interval",["day","time"])

# %%
a  = interval(day="wednesday", time="10-11")

# %%
a.day
# Out:
# 'wednesday'

# %%
d["A"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-43282a3086d8> in <module>()
# ----> 1 d["A"]
#
# KeyError: 'A'

# %%
[(d),
,
]

# %%
d :{
    "char": [intevals,,,]
}

# %%
df = pd.read_csv(r'C:\Users\idinn\Downloads\Copy of Class Time Table for 2020 Spring Semester_Version II - ')
